# %% [markdown]
# # MSDS696 Practicum 2
# ## Fall 8W2 2020
#
# ### Exploration of Colorado County-Level Voting Patterns 2010 - 2020
#
# #### James D. Reed (jreed011@regis.edu)
#
# <img src="../img/Mountains2.jpg" width="700" height="200" />
#
# ## Collect Census Data

# %%
import requests
import pandas as pd
#import censusdata
from pathlib import Path
import censusFunctions as cf
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from decouple import config
import os
# %matplotlib inline

# %%
global CENSUS_KEY
global GOOGLE_KEY

def get_census_keys():
    # Get CENSUS_KEY
    try:
        BASE_DIR = os.path.dirname(os.path.abspath(__file__))
    except NameError:  # We are the main py2exe script, not a module
        import sys
        BASE_DIR = os.path.dirname(os.path.abspath(sys.argv[0]))

    CENSUS = config('CENSUS_KEY')
    GOOGLE = config('GOOGLE_KEY')
    #print(f'CENSUS: {CENSUS}, GOOGLE: {GOOGLE}')
    return(CENSUS, GOOGLE)

# %%
CENSUS_KEY, GOOGLE_KEY = get_census_keys()
#print(f'CENSUS: {CENSUS_KEY}, GOOGLE: {GOOGLE_KEY}')

# %% [markdown]
# ---
# ## Decennial 2010 Census of Population
#
#  - Demographics (age, sex, race, family structure))
#  - Housing Occupancy and Ownership (vacant./occupied, rent/own)
#  - Group Quarters Population (prisons, college dorms)
#
# ### Build Population DataFrame

# %%
population_df = cf.get_population_df(CENSUS_KEY, 2010)

population_df.describe()
# Out:
# Population Dataframe shape: (64, 20)
#           total_pop  total_urb_rur          urban  urban_ins_ars  \
# count      64.00000       64.00000      64.000000      64.000000
# mean    78581.18750    78581.18750   67699.390625   60397.984375
# std    157027.62997   157027.62997  150562.413364  150552.140964
# min       699.00000      699.00000       0.000000       0.000000
# 25%      5734.00000     5734.00000       0.000000       0.000000
# 50%     15083.50000    15083.50000    5691.000000       0.000000
# 75%     42663.00000    42663.00000   22574.000000       0.000000
# max    622263.00000   622263.00000  600158.000000  600158.000000
#
#        urban_ins_cls         rural    total_race          white         black  \
# count       64.00000     64.000000      64.00000      64.000000     64.000000
# mean      7301.40625  10881.796875   78581.18750   63893.781250   3152.140625
# std      11475.32523  11537.590360  157027.62997  123363.297992  11450.748038
# ...

# %%
sub_file = cf.get_filename('population_df', 'Census2010')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/Census2010-population_df.p

# %%
pickle.dump(population_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ---
# ## Decennial 2010 Census - Gender
#
#  - Housing Occupancy and Ownership (vacant./occupied, rent/own)
#  - Group Quarters Population (prisons, college dorms)
#
# ### Build Gender DataFrame

# %%
gender_df = cf.get_gender_df(CENSUS_KEY, 2010)
gender_df.describe()
# Out:
# Gender Dataframe shape: (64, 52)
#        total_sex_byage     total_male       male_u5      male_5_9  \
# count         64.00000      64.000000     64.000000     64.000000
# mean       78581.18750   39385.343750   2755.640625   2777.843750
# std       157027.62997   77999.350262   5731.162580   5661.154448
# min          699.00000     362.000000      8.000000     22.000000
# 25%         5734.00000    3152.500000    144.750000    148.750000
# 50%        15083.50000    7837.000000    417.000000    426.500000
# 75%        42663.00000   21767.000000   1144.000000   1213.500000
# max       622263.00000  310162.000000  23152.000000  23050.000000
#
#          male_10_14   male_15_17    male_18_19      male_20      male_21  \
# count     64.000000     64.00000     64.000000    64.000000    64.000000
# mean    2659.250000   1611.56250   1134.218750   566.312500   550.906250
# std     5395.236132   3248.15466   2298.264297  1190.993435  1167.530642
# ...

# %%
sub_file = cf.get_filename('gender_df','Census2010')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/Census2010-gender_df.p

# %%
pickle.dump(gender_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ---
# ## Decennial 2010 Census 2010
#
# Housing survey
#  - Housing Occupancy and Ownership (vacant/occupied, rent/own)
#  - Group Quarters Population (prisons, college dorms)
#
# ### Build Housing DataFrame

# %%
housing_df = cf.get_housing_df(CENSUS_KEY,2010)
housing_df.describe()
# Out:
# Housing Dataframe shape: (64, 33)
#        total_house_tenure  total_occupied  households_fam  \
# count           64.000000       64.000000       64.000000
# mean         30826.062500    19711.359375    15178.078125
# std          62189.745293    38956.548991    29509.677221
# min            344.000000      156.000000      123.000000
# 25%           2011.500000     1343.250000     1172.500000
# 50%           6189.500000     3756.000000     2908.500000
# 75%          16508.500000    11074.000000     8755.750000
# max         263107.000000   160489.000000   123304.000000
#
#        households_husband_wife  households_other  households_other_male  \
# count                64.000000         64.000000              64.000000
# mean               4533.281250       1426.546875            3106.734375
# std                9690.349977       2931.714656            6768.228807
# min                  24.000000         10.000000              11.000000
# ...

# %%
sub_file = cf.get_filename('housing_df', 'Census2010')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/Census2010-housing_df.p

# %%
pickle.dump(housing_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ## American Community Survey 2019
#  - Educational Attainment
#  - Commuting (mode, time leaving, time travelled)
#  - Disability Status

# %%
acs19_pop_df = cf.get_acs19_pop(CENSUS_KEY,2019)
acs19_pop_df.describe()
# Out:
# ACS Dataframe shape: (27, 26)
#           pop_by_sex       pbs_male     pbs_female      pop_und18  \
# count      27.000000      27.000000      27.000000      27.000000
# mean   202878.740741  102171.592593  100707.148148   44359.703704
# std    241418.908512  120939.763246  120503.425702   54348.648811
# min     20356.000000   10402.000000    9052.000000       0.000000
# 25%     27898.500000   14273.500000   13285.500000    5876.500000
# 50%     56221.000000   30081.000000   28419.000000   11619.000000
# 75%    338675.000000  169891.000000  169049.000000   76664.500000
# max    727211.000000  364631.000000  362580.000000  171269.000000
#
#        pop_und18_by_age       pop_lt3       pop_3_5       pop_6_8  \
# count         27.000000     27.000000     27.000000     27.000000
# mean       44260.222222   6679.370370   7353.407407   7113.888889
# std        54213.912002   8381.356679   9458.239893   8736.908929
# min            0.000000      0.000000      0.000000      0.000000
# ...

# %%
sub_file = cf.get_filename('acs19_pop_df', 'ACS19')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/ACS19-acs19_pop_df.p

# %%
pickle.dump(acs19_pop_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ## American Community Survey 2019
#  - Marital Status:
#      + Never married
#      + Now married
#      + Separated
#      + Widowed
#      + Divorced

# %%
acs19_mar_df = cf.get_acs19_marital(CENSUS_KEY, 2019)
acs19_mar_df.describe()
# Out:
# ACS Dataframe shape: (27, 9)
#        total_marital  never_married    now_married    separated       widowed  \
# count      27.000000      27.000000      27.000000    27.000000     27.000000
# mean   166093.888889   53645.037037   84189.444444  2032.888889   6808.740741
# std    196969.366416   70056.734988   95888.613426  2723.136460   8014.699647
# min     17252.000000    3303.000000    9836.000000    43.000000    220.000000
# 25%     23051.000000    5549.000000   14000.000000   197.500000   1201.500000
# 50%     47675.000000   13830.000000   24411.000000   565.000000   1934.000000
# 75%    278456.500000   89012.000000  145282.500000  2489.000000  10920.000000
# max    608905.000000  260501.000000  305249.000000  8200.000000  25003.000000
#
#            divorced  state_id   county_id
# count     27.000000      27.0   27.000000
# mean   19417.777778       8.0   59.481481
# std    23145.732405       0.0   36.731217
# min     1931.000000       8.0    1.000000
# ...

# %%
sub_file = cf.get_filename('acs19_mar_df', 'ACS19')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/ACS19-acs19_mar_df.p

# %%
pickle.dump(acs19_mar_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ## 2019 1-Year Supplemental Estimates
#
# ### Poverty and Disability Estimates

# %%
acs19_pov_df = cf.get_acs19_poverty(CENSUS_KEY,2019)
acs19_pov_df.describe()
# Out:
# ACS Poverty Dataframe shape: (27, 39)
#        total_pov_hsh_type  total_below_pov  pov_below_married_cpl  \
# count           27.000000        27.000000              27.000000
# mean         48502.148148      2768.777778            1135.222222
# std          59204.825869      3393.806705            1346.230359
# min              0.000000         0.000000               0.000000
# 25%           6111.000000       284.500000              90.000000
# 50%          13458.000000      1077.000000             437.000000
# 75%          85551.500000      3894.000000            1775.500000
# max         182032.000000     11528.000000            4996.000000
#
#        pov_below_other  pov_below_other_male  pov_below_other_female  \
# count        27.000000             27.000000               27.000000
# mean       1633.555556            304.888889             1328.666667
# std        2093.911363            385.037294             1770.743629
# ...

# %%
sub_file = cf.get_filename('acs19_pov_df', 'ACS19')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/ACS19-acs19_pov_df.p

# %%
pickle.dump(acs19_pov_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ## 2019 1-Year Supplemental Estimates
#
# ### Household Income Estimates

# %%
acs19_inc_df = cf.get_acs19_income(CENSUS_KEY,2019)
acs19_inc_df.describe()
# Out:
# ACS Income Dataframe shape: (27, 27)
#         county total_hsh_inc hsh_inc_lt20 hsh_inc_20_40 hsh_inc_40_60  \
# count       27            27           27            27            27
# unique      27            27           27            27            27
# top     Teller         28062          262         15951         10854
# freq         1             1            1             1             1
#
#        hsh_inc_60_100 hsh_inc_100_150 hsh_inc_150_200 hsh_inc_200_plus  \
# count              27              27              27               27
# unique             27              27              27               27
# top             37990            1237           14050              690
# freq                1               1               1                1
#
#        med_household_inc  ... fam_inc_200_plus med_fam_inc med_nf_inc  \
# count                 27  ...               27          27         27
# unique                27  ...               27          27         27
# ...

# %%
sub_file = cf.get_filename('acs19_inc_df', 'ACS19')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/ACS19-acs19_inc_df.p

# %%
pickle.dump(acs19_inc_df, open(OUTPUT_DATA_PATH, "wb"))

# %% [markdown]
# ## 2019 1-Year Supplemental Estimates by Congressional District
#
# ### Household Income Estimates

# %%
acs19_cd_inc_df = cf.get_acs19_income(CENSUS_KEY,2019, geo = 'congressional')
acs19_cd_inc_df.describe()
# Out:
# ACS Income Dataframe shape: (7, 27)
#               congressional_dist total_hsh_inc hsh_inc_lt20 hsh_inc_20_40  \
# count                          7             7            7             7
# unique                         7             7            7             7
# top     Congressional District 5        368498        45554         33567
# freq                           1             1            1             1
#
#        hsh_inc_40_60 hsh_inc_60_100 hsh_inc_100_150 hsh_inc_150_200  \
# count              7              7               7               7
# unique             7              7               7               7
# top            46180          76691           61070           35806
# freq               1              1               1               1
#
#        hsh_inc_200_plus med_household_inc  ... fam_inc_200_plus med_fam_inc  \
# count                 7                 7  ...                7           7
# ...

# %%
acs19_cd_inc_df
# Out:
#          congressional_dist total_hsh_inc hsh_inc_lt20 hsh_inc_20_40  \
# 0  Congressional District 4        318691        29989         43544
# 1  Congressional District 1        368498        41554         51626
# 2  Congressional District 3        303788        45554         55759
# 3  Congressional District 2        333774        33759         36104
# 4  Congressional District 6        301487        20035         33567
# 5  Congressional District 5        305276        31599         48590
# 6  Congressional District 7        303589        24453         41532
#
#   hsh_inc_40_60 hsh_inc_60_100 hsh_inc_100_150 hsh_inc_150_200  \
# 0         38751          76691           65143           32157
# 1         47883          82626           67753           32784
# 2         50642          73549           44767           15486
# 3         38595          80299           61070           35431
# 4         44498          72207           58632           35806
# ...

# %%
sub_file = cf.get_filename('acs19_inc_df', 'ACS19')
OUTPUT_DATA_PATH = Path().absolute().parent / "data" / "processed" / sub_file
print(OUTPUT_DATA_PATH)
# Out:
# /home/jdreed/MSDS696/data/processed/ACS19-acs19_inc_df.p

# %%
pickle.dump(acs19_inc_df, open(OUTPUT_DATA_PATH, "wb"))

# %%
from datetime import date
print(f'Complete: {date.today()}')
# Out:
# Complete: 2020-11-12
